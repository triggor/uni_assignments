# %% [markdown]
# # Assignment 4
#
# **Submission deadline: last lab session before or on Wednesday, 22.11.17**
#
# **Points: 11 + 4 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %% [markdown]
# # Starter code: network for Irises in Pytorch
#
#
# In the following cells a feedforward neural network has been implemented with the aid of PyTorch and its autograd mechanism. Please study the code - many network implementations follow a similar pattern.
#
# The provided network trains to nearly 100% accuracy on Iris using Batch Gradient Descent.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch.autograd import Variable


class Layer(object):
    
    def train_mode(self):
        """Put layer into training mode.
        """
        pass
    
    def eval_mode(self):
        """Put layer into evalation mode.
        """
        pass
    
    @property
    def parameters(self):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out):
        self.W = Variable(torch.FloatTensor(num_in, num_out),
                          requires_grad=True)
        self.W.name = 'W'
        self.b = Variable(torch.FloatTensor(1, num_out),
                          requires_grad=True)
        self.b.name = 'b'
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    def forward(self, x):
        return x.mm(self.W) + self.b

    
class TanhLayer(Layer):
    def forward(self, x):
        return F.tanh(x)

    
class  ReLULayer(Layer):
    def forward(self, x):
        return F.relu(x)


class SoftMaxLayer(Layer):
    def forward(self, x):
        return F.softmax(x)
    
class DropoutLayer(Layer):
    def __init__(self, p=0.5):
        self.p = p
    
    def train_mode(self):
        self.in_place = True
        pass
    
    def eval_mode(self):
        self.in_place = False
        pass
    
    def forward(self, x):
        return F.dropout(x, self.p, self.in_place)

# %%
class FeedforwardNet(object):
    def __init__(self, layers):
        self.layers = layers

    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params

    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP.data = newP.data
    
    def train_mode(self):
        for layer in self.layers:
            layer.train_mode()
    
    def eval_mode(self):
        for layer in self.layers:
            layer.eval_mode()    
    
    def forward(self, x):
        for layer in self.layers:
            x = layer.forward(x)
        return x
    
    def loss(self, outputs, targets):
        return torch.mean(-torch.log(torch.gather(
            outputs, 1, targets.unsqueeze(1))))

# %%
from sklearn import datasets
import torchvision


iris = datasets.load_iris()
IrisX = iris.data.astype(np.float32)
IrisX = (IrisX - IrisX.mean(axis=0, keepdims=True)) / IrisX.std(axis=0, keepdims=True)
IrisY = iris.target

def GD(model, x, y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """Simple batch gradient descent"""
    try:
        old_loss = np.inf
        x = Variable(torch.from_numpy(x), requires_grad=False)
        y = Variable(torch.from_numpy(y.astype(np.int64)), requires_grad=False)
        
        model.train_mode()
        for i in xrange(max_iters):
            outputs = model.forward(x)
            loss = model.loss(outputs, y)

            loss.backward()
            for p in model.parameters:
                p.data -= p.grad.data * alpha
                # Zero gradients for the next iteration
                p.grad.data.zero_()

            loss = loss.data[0]
            if old_loss < loss:
                print "Iter: %d, loss increased!" % (i,)
            if (old_loss - loss) < tolerance:
                print "Tolerance level reached. Exiting."
                break
            if i % 1000 == 0:
                _, predictions = outputs.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / outputs.size(0)
                print "Iteration {0: >6} | loss {1: >5.2f} | err rate  {2: >5.2f}%" \
                      .format(i, loss, err_rate)
            old_loss = loss
    except KeyboardInterrupt:
        pass

# %%
model = FeedforwardNet(
    [AffineLayer(4, 10),
     TanhLayer(),
     DropoutLayer(),
     AffineLayer(10, 5),
     SoftMaxLayer(),
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        #p.data.normal_(0, 0.05)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# Train
GD(model, IrisX, IrisY, alpha=1e-1, tolerance=1e-7)
# Out:
# Iteration      0 | loss  1.61 | err rate  89.33%
# Iter: 38, loss increased!
# Tolerance level reached. Exiting.
# /home/igort/anaconda3/envs/my_env/lib/python2.7/site-packages/ipykernel_launcher.py:53: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.

# %% [markdown]
# # Starter code for MNIST and SGD scaffolding

# %%
import torch
import torchvision
import os


batch_size = 128
data_path = os.environ.get('PYTORCH_DATA_PATH', '../data')

transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor(),
     
     torchvision.transforms.Normalize((0.1307,), (0.3081,)),
    ])

_test = torchvision.datasets.MNIST(
    data_path, train=False, download=True, transform=transform)

# Load training data, split into train and valid sets
_train = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_train.train_data = _train.train_data[:50000]
_train.train_labels = _train.train_labels[:50000]

_valid = torchvision.datasets.MNIST(
    data_path, train=True, download=True, transform=transform)
_valid.train_data = _valid.train_data[50000:]
_valid.train_labels = _valid.train_labels[50000:]

mnist_loaders = {
    'train': torch.utils.data.DataLoader(
        _train, batch_size=batch_size, shuffle=True),
    'valid': torch.utils.data.DataLoader(
        _valid, batch_size=batch_size, shuffle=False),
    'test': torch.utils.data.DataLoader(
        _test, batch_size=batch_size, shuffle=False)}
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
def compute_error_rate(model, data_loader, cuda=False):
    model.eval_mode()
    num_errs = 0.0
    num_examples = 0
    for x, y in data_loader:
        if cuda:
            x = x.cuda()
            y = y.cuda()
        x = Variable(x.view(x.size(0), -1), volatile=True)
        y = Variable(y, volatile=True)
        outputs = model.forward(x)
        _, predictions = outputs.data.max(dim=1)
        num_errs += (predictions != y.data).sum()
        num_examples += x.size(0)
    return 100.0 * num_errs / num_examples

def SGD(model, data_loaders, alpha=1e-4, num_epochs=1, patience_expansion=1.5,
        log_every=100, cuda=False):
    if cuda:
        for p in model.parameters:
            p.data = p.data.cuda()
    #
    # TODO: Initialize momentum variables
    # Hint: You need one velocity matrix for each parameter
    #
    velocities = [np.zeros(pars.data.shape) for pars in model.parameters]
    #
    iter_ = 0
    epoch = 0
    best_params = None
    best_val_err = np.inf
    history = {'train_losses': [], 'train_errs': [], 'val_errs': []}
    print('Training the model!')
    print('Interrupt at any time to evaluate the best validation model so far.')
    try:
        while epoch < num_epochs:
            
            model.train_mode()
            
            epoch += 1
            for x, y in data_loaders['train']:
                if cuda:
                    x = x.cuda()
                    y = y.cuda()
                iter_ += 1
                x = Variable(x.view(x.size(0), -1), requires_grad=False)
                y = Variable(y, requires_grad=False)
                
                out = model.forward(x)
                loss = model.loss(out, y)
                
                loss.backward()
                _, predictions = out.data.max(dim=1)
                err_rate = 100.0 * (predictions != y.data).sum() / out.size(0)

                history['train_losses'].append(loss.data[0])
                history['train_errs'].append(err_rate)

                for p, v in zip(model.parameters, velocities):
                    if p.name == 'W':
                        pass
                    #
                    # TODO: Implement weight decay addition to gradients
                    p.grad.data += p.data * 1e-4
                    # 
                    
                    #
                    # TODO: Update learning rate
                    # Hint: Use the iteration counter i
                    alpha = alpha * 0.99999999995**iter_ 
                    #
                    
                    #
                    # TODO: Set the momentum constant 
                    epsilon = 0.2
                    #
#                     try:
#                     print ('p.grad.data: ', p.grad.data.shape)
#                     print ('v: ', v.shape)
#                     print ('velocities: ', np.array(velocities).shape)
#                     print ('velocities[0]: ', np.array(velocities[0]).shape)
#                     except Exception:
#                         break
#                     break
                    #
                    # TODO: Implement velocity update in momentum
                    #v[...] = (epsilon * torch.Tensor(v)) +
                    v =  alpha * p.grad.data
#                     if(iter_ > 0):
#                         velocities[iter_] = epsilon * v
                        #v =  alpha * p.grad.data # + velocities[iter_-1]
                    
                    
                    #
                    
                    #
                    # TODO: Set a more sensible learning rule here,
                    #       using your learning rate schedule and momentum
                    # 
                    #p.data -= alpha * p.grad.data
                    p.data -= v
                    # Zero gradients for the next iteration
                    p.grad.data.zero_()

                if iter_ % log_every == 0:
                    print "Minibatch {0: >6}  | loss {1: >5.2f} | err rate {2: >5.2f}%" \
                          .format(iter_, loss.data[0], err_rate)
            
            val_err_rate = compute_error_rate(model, data_loaders['valid'], cuda)
            history['val_errs'].append((iter_, val_err_rate))
            
            if val_err_rate < best_val_err:
                # Adjust num of epochs
                num_epochs = int(np.maximum(num_epochs, epoch * patience_expansion + 1))
                best_epoch = epoch
                best_val_err = val_err_rate
                best_params = [p.clone().cpu() for p in model.parameters]
            m = "After epoch {0: >2} | valid err rate: {1: >5.2f}% | doing {2: >3} epochs" \
                .format(epoch, val_err_rate, num_epochs)
            print '{0}\n{1}\n{0}'.format('-' * len(m), m)

    except KeyboardInterrupt:
        pass
    if best_params is not None:
        print "\nLoading best params on validation set (epoch %d)\n" %(best_epoch)
        model.parameters = best_params
    plot_history(history)

def plot_history(history):
    figsize(16, 4)
    subplot(1,2,1)
    train_loss = np.array(history['train_losses'])
    semilogy(np.arange(train_loss.shape[0]), train_loss, label='batch train loss')
    legend()
        
    subplot(1,2,2)
    train_errs = np.array(history['train_errs'])
    plot(np.arange(train_errs.shape[0]), train_errs, label='batch train error rate')
    val_errs = np.array(history['val_errs'])
    plot(val_errs[:,0], val_errs[:,1], label='validation error rate', color='r')
    ylim(0,20)
    legend()

# %% [markdown]
# # Problem 2: Tuning the Network for MNIST [4p]
#
# Tune the following network to reach **validation error rate below 1.9%**.
# This should result in a **test error rate below 2%**. To
# tune the network you will need to:
# 1. Choose the number of layers (more than 1, less than 5);
# 2. Choose the number of neurons in each layer (more than 100,
#     less than 5000);
# 3. Pick proper weight initialization;
# 4. Pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches);
# 5. Pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: Pick a network architecture here.
#       The one below is just softmax regression.
#

model = FeedforwardNet(
    [
     AffineLayer(784, 120),
     ReLULayer(),
     DropoutLayer(),   
     AffineLayer(120, 16),
     #DropoutLayer(),
     ReLULayer(),
     #DropoutLayer(),
     AffineLayer(16, 10),
     #DropoutLayer(),
     SoftMaxLayer()
    ])

# Initialize parameters
for p in model.parameters:
    if p.name == 'W':
        #p.data.normal_(0, 0.05)
        p.data.uniform_(-0.1, 0.1)
    elif p.name == 'b':
        p.data.zero_()
    else:
        raise ValueError('Unknown parameter name "%s"' % p.name)

# On lab computers you can set cuda=True !
SGD(model, mnist_loaders, alpha=2e-1, cuda=False)

print "Test error rate: %.2f%%" % compute_error_rate(model, mnist_loaders['test'])
# Out:
# Training the model!
# Interrupt at any time to evaluate the best validation model so far.
# /home/igort/anaconda3/envs/my_env/lib/python2.7/site-packages/ipykernel_launcher.py:53: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Minibatch    100  | loss  0.64 | err rate 24.22%
# Minibatch    200  | loss  0.47 | err rate 15.62%
# Minibatch    300  | loss  0.50 | err rate 13.28%
# ----------------------------------------------------------
# After epoch  1 | valid err rate:  6.28% | doing   2 epochs
# ----------------------------------------------------------
# Minibatch    400  | loss  0.33 | err rate 10.16%
# Minibatch    500  | loss  0.30 | err rate  7.03%
# Minibatch    600  | loss  0.23 | err rate  7.03%
# Minibatch    700  | loss  0.23 | err rate  7.81%
# ----------------------------------------------------------
# After epoch  2 | valid err rate:  4.16% | doing   4 epochs
# ----------------------------------------------------------
# Minibatch    800  | loss  0.20 | err rate  5.47%
# Minibatch    900  | loss  0.32 | err rate  9.38%
# Minibatch   1000  | loss  0.19 | err rate  7.03%
# Minibatch   1100  | loss  0.27 | err rate  6.25%
# ----------------------------------------------------------
# After epoch  3 | valid err rate:  3.74% | doing   5 epochs
# ----------------------------------------------------------
# Minibatch   1200  | loss  0.24 | err rate  6.25%
# Minibatch   1300  | loss  0.15 | err rate  4.69%
# Minibatch   1400  | loss  0.15 | err rate  4.69%
# Minibatch   1500  | loss  0.19 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  4 | valid err rate:  3.27% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   1600  | loss  0.14 | err rate  3.91%
# Minibatch   1700  | loss  0.18 | err rate  3.91%
# Minibatch   1800  | loss  0.11 | err rate  3.12%
# Minibatch   1900  | loss  0.28 | err rate  5.47%
# ----------------------------------------------------------
# After epoch  5 | valid err rate:  3.29% | doing   7 epochs
# ----------------------------------------------------------
# Minibatch   2000  | loss  0.16 | err rate  4.69%
# Minibatch   2100  | loss  0.23 | err rate  7.03%
# Minibatch   2200  | loss  0.22 | err rate  7.81%
# Minibatch   2300  | loss  0.47 | err rate 13.28%
# ----------------------------------------------------------
# After epoch  6 | valid err rate:  3.20% | doing  10 epochs
# ----------------------------------------------------------
# Minibatch   2400  | loss  0.20 | err rate  7.81%
# Minibatch   2500  | loss  0.08 | err rate  1.56%
# Minibatch   2600  | loss  0.25 | err rate  7.81%
# Minibatch   2700  | loss  0.26 | err rate  7.03%
# ----------------------------------------------------------
# After epoch  7 | valid err rate:  2.92% | doing  11 epochs
# ----------------------------------------------------------
# Minibatch   2800  | loss  0.12 | err rate  4.69%
# Minibatch   2900  | loss  0.11 | err rate  3.12%
# Minibatch   3000  | loss  0.16 | err rate  3.12%
# Minibatch   3100  | loss  0.13 | err rate  4.69%
# ----------------------------------------------------------
# After epoch  8 | valid err rate:  2.84% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3200  | loss  0.10 | err rate  3.12%
# Minibatch   3300  | loss  0.16 | err rate  4.69%
# Minibatch   3400  | loss  0.25 | err rate  7.03%
# Minibatch   3500  | loss  0.11 | err rate  3.12%
# ----------------------------------------------------------
# After epoch  9 | valid err rate:  2.85% | doing  13 epochs
# ----------------------------------------------------------
# Minibatch   3600  | loss  0.14 | err rate  2.34%
# Minibatch   3700  | loss  0.21 | err rate  4.69%
# Minibatch   3800  | loss  0.11 | err rate  3.91%
# Minibatch   3900  | loss  0.18 | err rate  5.47%
# ----------------------------------------------------------
# After epoch 10 | valid err rate:  2.76% | doing  16 epochs
# ----------------------------------------------------------
# Minibatch   4000  | loss  0.13 | err rate  4.69%
# Minibatch   4100  | loss  0.19 | err rate  4.69%
# Minibatch   4200  | loss  0.09 | err rate  4.69%
# Minibatch   4300  | loss  0.28 | err rate  8.59%
# ----------------------------------------------------------
# After epoch 11 | valid err rate:  2.60% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4400  | loss  0.20 | err rate  5.47%
# Minibatch   4500  | loss  0.11 | err rate  4.69%
# Minibatch   4600  | loss  0.13 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 12 | valid err rate:  2.73% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   4700  | loss  0.07 | err rate  1.56%
# Minibatch   4800  | loss  0.10 | err rate  2.34%
# Minibatch   4900  | loss  0.13 | err rate  5.47%
# Minibatch   5000  | loss  0.13 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 13 | valid err rate:  2.67% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   5100  | loss  0.16 | err rate  3.91%
# Minibatch   5200  | loss  0.10 | err rate  3.91%
# Minibatch   5300  | loss  0.15 | err rate  5.47%
# Minibatch   5400  | loss  0.10 | err rate  3.12%
# ----------------------------------------------------------
# After epoch 14 | valid err rate:  2.60% | doing  17 epochs
# ----------------------------------------------------------
# Minibatch   5500  | loss  0.18 | err rate  3.91%
# Minibatch   5600  | loss  0.17 | err rate  4.69%
# Minibatch   5700  | loss  0.09 | err rate  3.91%
# Minibatch   5800  | loss  0.07 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 15 | valid err rate:  2.56% | doing  23 epochs
# ----------------------------------------------------------
# Minibatch   5900  | loss  0.09 | err rate  1.56%
# Minibatch   6000  | loss  0.12 | err rate  3.91%
# Minibatch   6100  | loss  0.14 | err rate  3.12%
# Minibatch   6200  | loss  0.23 | err rate  6.25%
# ----------------------------------------------------------
# After epoch 16 | valid err rate:  2.42% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6300  | loss  0.20 | err rate  8.59%
# Minibatch   6400  | loss  0.15 | err rate  3.91%
# Minibatch   6500  | loss  0.07 | err rate  1.56%
# Minibatch   6600  | loss  0.18 | err rate  6.25%
# ----------------------------------------------------------
# After epoch 17 | valid err rate:  2.58% | doing  25 epochs
# ----------------------------------------------------------
# Minibatch   6700  | loss  0.15 | err rate  3.91%
# Minibatch   6800  | loss  0.11 | err rate  3.91%
# Minibatch   6900  | loss  0.26 | err rate  3.91%
# Minibatch   7000  | loss  0.06 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 18 | valid err rate:  2.23% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7100  | loss  0.16 | err rate  5.47%
# Minibatch   7200  | loss  0.05 | err rate  2.34%
# Minibatch   7300  | loss  0.13 | err rate  3.91%
# Minibatch   7400  | loss  0.25 | err rate  8.59%
# ----------------------------------------------------------
# After epoch 19 | valid err rate:  2.42% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7500  | loss  0.32 | err rate  8.59%
# Minibatch   7600  | loss  0.15 | err rate  6.25%
# Minibatch   7700  | loss  0.24 | err rate  6.25%
# Minibatch   7800  | loss  0.19 | err rate  5.47%
# ----------------------------------------------------------
# After epoch 20 | valid err rate:  2.63% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   7900  | loss  0.10 | err rate  3.12%
# Minibatch   8000  | loss  0.16 | err rate  3.12%
# Minibatch   8100  | loss  0.21 | err rate  7.03%
# Minibatch   8200  | loss  0.14 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 21 | valid err rate:  2.38% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   8300  | loss  0.15 | err rate  3.12%
# Minibatch   8400  | loss  0.04 | err rate  0.00%
# Minibatch   8500  | loss  0.14 | err rate  3.91%
# Minibatch   8600  | loss  0.11 | err rate  2.34%
# ----------------------------------------------------------
# After epoch 22 | valid err rate:  2.50% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   8700  | loss  0.16 | err rate  6.25%
# Minibatch   8800  | loss  0.15 | err rate  4.69%
# Minibatch   8900  | loss  0.05 | err rate  1.56%
# ----------------------------------------------------------
# After epoch 23 | valid err rate:  2.48% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   9000  | loss  0.14 | err rate  5.47%
# Minibatch   9100  | loss  0.16 | err rate  3.91%
# Minibatch   9200  | loss  0.07 | err rate  2.34%
# Minibatch   9300  | loss  0.04 | err rate  0.78%
# ----------------------------------------------------------
# After epoch 24 | valid err rate:  2.30% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   9400  | loss  0.16 | err rate  5.47%
# Minibatch   9500  | loss  0.13 | err rate  3.91%
# Minibatch   9600  | loss  0.17 | err rate  6.25%
# Minibatch   9700  | loss  0.09 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 25 | valid err rate:  2.48% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch   9800  | loss  0.12 | err rate  3.91%
# Minibatch   9900  | loss  0.15 | err rate  4.69%
# Minibatch  10000  | loss  0.05 | err rate  0.78%
# Minibatch  10100  | loss  0.11 | err rate  4.69%
# ----------------------------------------------------------
# After epoch 26 | valid err rate:  2.29% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  10200  | loss  0.08 | err rate  2.34%
# Minibatch  10300  | loss  0.06 | err rate  2.34%
# Minibatch  10400  | loss  0.06 | err rate  3.12%
# Minibatch  10500  | loss  0.14 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 27 | valid err rate:  2.34% | doing  28 epochs
# ----------------------------------------------------------
# Minibatch  10600  | loss  0.14 | err rate  3.12%
# Minibatch  10700  | loss  0.13 | err rate  5.47%
# Minibatch  10800  | loss  0.08 | err rate  3.12%
# Minibatch  10900  | loss  0.14 | err rate  3.91%
# ----------------------------------------------------------
# After epoch 28 | valid err rate:  2.41% | doing  28 epochs
# ----------------------------------------------------------
#
# Loading best params on validation set (epoch 18)
#
# Test error rate: 2.64%
